# %%
# Utils #
import random
from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import itertools

from scipy.optimize import minimize
from scipy.linalg import sqrtm
import time

''' Fundemental Operations'''

# Functions
def sigmoid(x): return 1 / (1 + np.exp(-x))
def log_gaussian(x, mean, cov_inv):
    if np.array(x).ndim==1:  x = x.reshape(1,-1)
    return -(1/2) * np.sum((x - mean) @ (cov_inv) * (x - mean), axis=1)

# Models
def MIRT(ps, qs):
    ps_, qs_ = ps, qs
    if np.array(qs).ndim==1:  qs_ = [qs]
    if np.array(ps).ndim==1:  ps_ = [ps]
    r = np.prod(sigmoid(np.array([qs_] * len(ps_)) + np.array([ps_] * len(qs_)).swapaxes(0,1)), axis=2)
    return r

def LN(ps, qs):
    ps_, qs_ = ps, qs
    if np.array(qs).ndim==1:  qs_ = qs.reshape(1,-1)
    if np.array(ps).ndim==1:  ps_ = ps.reshape(1,-1)
    r = sigmoid(ps_@qs_.T[:-1] + qs_.T[1])
    return r

# Basic Pipelines
class Record():
    def __init__(self):
        self.typs = ['MAP', 'nHess', 'f', 'true_f', 'time', 'ent']
        self.data = { typ:[] for typ in self.typs }

    def merge(self, subRecord):
        for typ in self.typs:
            self.data[typ].append(subRecord.data[typ])

class Belief():
    """
    Class Representation of Bayesian Belief.
    """
    def __init__(self, f, dim, MAP_0, nHess_0):
        self.dim = dim # dimension
        self.f = f # set correct rate function
        
        if self.f == LN :
            self.func_name = 'LN'
        else :
            self.func_name = 'MIRT'

        print(self.func_name)

        self.MAP_0 = MAP_0
        self.nHess_0 = nHess_0
        self.ent_0 = 0
        self.LPrior = lambda theta : log_gaussian(theta, mean=self.MAP_0, cov_inv=self.nHess_0)
        
        self.sample_points = self.pre_sampling_points(num_sampling=3000)
        self.initialize(self.MAP_0, self.nHess_0)
        self.par_0 = {'MAP_0' : self.MAP_0, 'nHess_0' : self.nHess_0, 'ent_0' : self.ent_0}

    def initialize(self, MAP_0, nHess_0): # clear history
        self.t, self.MAP, self.nHess = 0, MAP_0, nHess_0
        self.LL_t = [self.LPrior] # Log Likelihood at step t
        self.x_t = []
        self.y_t = []

        self.ent_0 = self.calculate_diff_ent()
        self.ent = self.ent_0

        self.Record = Record()
        self.Record.data['MAP'].append(self.MAP)
        self.Record.data['nHess'].append(self.nHess)
        self.Record.data['ent'].append(self.ent)
    
    def pre_sampling_points(self,num_sampling) :
        return np.random.multivariate_normal(np.zeros(self.dim), np.eye(self.dim), num_sampling)

    def calculate_diff_ent(self) :
        p_pdf = lambda theta: np.exp(np.sum([self.LL_t[L_idx](theta) for L_idx in range(len(self.LL_t))], axis=0))
        q_pdf = lambda theta: ((2*np.pi) ** (-self.dim/2)) * (np.linalg.det(self.nHess)**0.5) * np.exp(-(1/2) * np.sum((theta - self.MAP) @ (self.nHess) * (theta - self.MAP), axis=1))
        theta_points = self.MAP + (sqrtm(np.linalg.inv(self.nHess)) @ self.sample_points.T).T
        p_pdf_vals = p_pdf(theta_points)
        q_pdf_vals = q_pdf(theta_points)
        epsilon = 1e-40
        p_pdf_vals = np.maximum(p_pdf_vals,epsilon)
        q_pdf_vals = np.maximum(q_pdf_vals,epsilon)
        
        diff_ent = np.mean(- (p_pdf_vals / q_pdf_vals) * np.log(p_pdf_vals))
        return diff_ent
    
    def bayesian_update(self, x, y):
        LL = lambda theta : np.log( self.f(theta, x).reshape(-1) if y==1 else 1-self.f(theta, x).reshape(-1) ) # Log Likelihood
        self.LL_t.append(LL)
        self.x_t.append(x)
        self.y_t.append(y)
        
        NLPosterior = lambda theta : -sum([self.LL_t[L_idx](theta) for L_idx in range(len(self.LL_t))])
        func = NLPosterior

        # Analytic gradient and hessian of each models
        if self.func_name == 'LN' :
            gradient = lambda theta : (theta - self.MAP_0) @ self.nHess_0 + sum([ self.x_t[idx][:-1] * (self.f(theta,self.x_t[idx]).reshape(-1) - self.y_t[idx]) 
                                                                                 for idx in range(len(self.x_t))])
            hessian = lambda theta : self.nHess_0 + sum([ self.x_t[idx][:-1].T @ self.x_t[idx][:-1] * (1 - self.f(theta,self.x_t[idx]).reshape(-1)) * self.f(theta,self.x_t[idx]).reshape(-1) 
                                                         for idx in range(len(self.x_t))])
        
        #### sometimes occur that hessian's determinant became negative, please chech the BNS formulations for this types of error occuring.
        elif self.func_name == 'MIRT' : 
            gradient = lambda theta : ((theta - self.MAP_0) @ self.nHess_0).reshape(-1) - sum([ (self.y_t[idx]  - (1 - self.y_t[idx]) * self.f(theta, self.x_t[idx] / (1-self.f(theta, self.x_t[idx])))) * (1 - sigmoid(self.x_t[idx] + theta)) 
                                                                                               for idx in range(len(self.y_t))]).reshape(-1)
            hessian = lambda theta : self.nHess_0 + sum([( (1 - self.y_t[idx]) * self.f(theta,self.x_t[idx]) / (1-self.f(theta,self.x_t[idx])) + self.y_t[idx]) * np.diag(sigmoid(self.x_t[idx] + theta).reshape(-1) * (1 - sigmoid(self.x_t[idx] + theta).reshape(-1))) 
                                                         + (1 - self.y_t[idx]) * (1 - sigmoid(self.x_t[idx] + theta)).T @ (1 - sigmoid(self.x_t[idx] + theta)) * self.f(theta,self.x_t[idx]) / ((1-self.f(theta,self.x_t[idx]))**2) 
                                                         for idx in range(len(self.x_t))])

        # Laplace Approximation
        opt_response = minimize(func, self.MAP, jac=gradient, hess=hessian, method='trust-ncg')
        self.MAP = opt_response.x
        self.nHess = hessian(self.MAP)
        self.ent = self.calculate_diff_ent()
        self.t += 1
        self.Record.data['MAP'].append(self.MAP)
        self.Record.data['nHess'].append(self.nHess)
        self.Record.data['ent'].append(self.ent)

        print("time step " + str(self.t))
        print("differential Entropy : ")
        print(self.ent)
        print("approx differential Entropy : ")
        print(0.5 * (self.dim * np.log(2 * np.pi * np.e) - np.log(np.linalg.det(self.nHess))))
        print("L2 norm : ")
        true_theta = np.array([0.9, 0.3, 0.3, 0.1])

        #true_theta = np.array([0, 0, 0, 0])
        print(np.sum((true_theta - self.MAP)**2))

# Sampling Importance Sampling
def SIR(Belief, iterations) :
    true_pdf = lambda theta: np.exp(np.sum([Belief.LL_t[L_idx](theta) for L_idx in range(len(Belief.LL_t))], axis=0))
    proposal_pdf = lambda theta: ((2*np.pi) ** (-Belief.dim/2)) * (np.linalg.det(Belief.nHess)**0.5) * np.exp(-(1/2) * np.sum((theta - Belief.MAP) @ (Belief.nHess) * (theta - Belief.MAP), axis=1))
    
    samples = Belief.MAP + (sqrtm(np.linalg.inv(Belief.nHess)) @ Belief.sample_points.T).T
    N = len(samples)

    for _ in range(iterations) :
        weights = true_pdf(samples) / proposal_pdf(samples)
        weights = weights / np.sum(weights)
        indices = np.random.choice(N, N, p = weights)
        samples = samples[indices]
    
    return samples

''' Synthetic case Operations '''

# Algo
class DURM_LN():
    def __init__(self, alpha):
        self.alpha = alpha

    def query(self, Belief):
        val, vec = np.linalg.eig(Belief.nHess)
        x_1 = self.alpha * vec[:, np.argmin(val)]
        x_0 = - x_1.T @ Belief.MAP
        return np.append(x_1,x_0)

class DURM_MIRT():
    def __init__(self, alpha):
        self.alpha = alpha
    
    def query(self, Belief):
        ### We regarding Only for diagonal component cases ###
        component_idx = np.argmin(Belief.nHess @ np.ones(len(Belief.nHess)).T)
        x = 1e7 * np.ones(len(Belief.nHess))
        x[component_idx] = - Belief.MAP[component_idx]
        return x

# Experiments
class Experiment_Synthetic():
    def __init__(self, Algo, dim, f, true_theta, num_t, MAP_0, nHess_0):
        self.Algo = Algo
        self.dim = dim
        self.f = f
        self.true_theta = true_theta
        self.num_t = num_t
        self.MAP_0 = MAP_0
        self.nHess_0 = nHess_0
    
    def iter_t(self):
        self.Belief = Belief(self.f, self.dim, self.MAP_0, self.nHess_0)
        self.Belief.initialize(self.MAP_0, self.nHess_0)
        self.answers = np.random.uniform(0,1,self.num_t)
        
        while self.Belief.t < self.num_t:
            start_time = time.time()
            
            # Query suggestion by Algorithm
            x = self.Algo.query(self.Belief)
            self.Belief.Record.data['true_f'].append(true_f := self.Belief.f(self.true_theta, x))
            self.Belief.Record.data['f'].append(self.Belief.f(self.Belief.MAP, x))

            # Belief by Bayesian update
            y = 1 if self.answers[self.Belief.t] < true_f else 0
            self.Belief.bayesian_update(x, y)

            end_time = time.time()
            self.Belief.Record.data['time'].append(end_time-start_time)
        return self.Belief.Record
    
def Run_Synthetic(model_name, dim, alpha, true_theta, num_t, MAP_0, nHess_0, iterations) :
    if model_name == 'MIRT' :
        f = MIRT
        Algo = DURM_MIRT(alpha)
    else :
        f = LN
        Algo = DURM_LN(alpha)

    Data = []
    exp = Experiment_Synthetic(Algo, dim, f, true_theta, num_t, MAP_0, nHess_0)
    for iter in tqdm(range(iterations)) :
        data = exp.iter_t()
        Data.append(data)
        print(iter)
    Data = np.array(Data)
    np.save("Synthetic_" + model_name + "_" + str(dim) + ".npy",Data)

''' Realworld case Operations '''

# Algo
class DURM():
    def __init__(self, model):
        self.f = model
        
    def query(self, Belief, queries):
        MAP = Belief.MAP
        val, vec = np.linalg.eig(Belief.nHess)
        vec_min = vec[:,np.argmin(val)]
        delta = 1e-4
        idx = np.argmax(np.array([(self.f(MAP + delta * vec_min,queries[q_idx]) - self.f(MAP - delta * vec_min,queries[q_idx]))**2 for q_idx in range(len(queries))]).reshape(-1))
        return idx

class BALD():
    def __init__(self, model):
        self.f = model

    def query(self, Belief, queries):
        samples = SIR(Belief, 10)
        
        # f(samples, queries) 결과 한 번 계산
        f_samples_queries = self.f(samples, queries)
        M = len(samples)
        H1_pos = (np.sum(f_samples_queries, axis=0) / M) * np.log(np.sum(f_samples_queries, axis=0)/M) 
        H1_neg = (np.sum(1 - f_samples_queries, axis=0) / M) * np.log(np.sum(1 - f_samples_queries, axis=0)/M)
        H1 = H1_pos + H1_neg
        
        H2 = np.sum(f_samples_queries * np.log(f_samples_queries) + (1 - f_samples_queries) * np.log(1 - f_samples_queries), axis=0) / M
        
        gain = H1 - H2
        idx = np.argmax(gain)
        return idx

# Experiments
class Experiment_Realworld():
    def __init__(self, Algo, dim, f, num_t, MAP_0, nHess_0, R, P, Q, PQI):
        self.Algo = Algo
        self.dim = dim
        self.f = f
        self.num_t = num_t
        self.MAP_0 = MAP_0
        self.nHess_0 = nHess_0
        
        self.R = R
        self.P = P
        self.Q = Q
        self.PQI = PQI
    
    def do(self, populate_idx) :
        Data = []
        for i in tqdm(populate_idx) :
            
            self.Belief = Belief(self.f, self.dim, self.MAP_0, self.nHess_0)
            
            if self.num_t < len(self.PQI[i]) :
                self.true_theta = self.P[i]
                
                self.Belief.initialize(self.MAP_0, self.nHess_0)
                while self.Belief.t < self.num_t:
                    start_time = time.time()
                    
                    # Query suggestion by Algorithm
                    idx = self.Algo.query(self.Belief, self.Q[self.PQI[i]])
                    self.Belief.Record.data['true_f'].append(true_f := self.Belief.f(self.true_theta, self.Q[self.PQI[i][idx]]))
                    self.Belief.Record.data['f'].append(self.Belief.f(self.Belief.MAP, self.Q[self.PQI[i][idx]]))

                    self.Belief.bayesian_update(self.Q[self.PQI[i][idx]], self.R[i][self.PQI[i][idx]])
                    self.PQI[i].pop(idx)
                    
                    end_time = time.time()
                    self.Belief.Record.data['time'].append(end_time - start_time)

            Data.append(self.Belief.Record)
        return Data

def Run_RealWorld(algorithm_name, model_name, dim, pop_num) :
    if model_name == "MIRT" :
        model = MIRT
    else :
        model = LN

    R = np.load("RealWorld_dataset/" + model_name+ "_Dataset.npy")
    n_p, n_q = R.shape
    obs = ~np.isnan(R)
    max_query_num = np.min([np.sum(obs[j]) for j in range(len(obs))])

    possible_query_idx = []
    for i in range(obs.shape[0]):
        true_indices = np.where(obs[i])
        possible_query_idx.append(true_indices[0])
        
    PQIs = []

    for i in range(len(possible_query_idx)) :
        PQIs.append(possible_query_idx[i].tolist())
    PQI = PQIs

    P = np.load("RealWorld_dataset/Theta_" + model_name + "_" + str(dim) + "_MSE.npy")
    Q = np.load("RealWorld_dataset/Query_" + model_name + "_" + str(dim) + "_MSE.npy")

    num_t = 100

    mean = np.mean(P,axis=0)
    cov = np.cov(P.T)
    MAP_0 = mean
    nHess_0 = np.linalg.inv(cov)

    # pop_num < len(P)
    populate_idx = np.array([p_id for p_id in range(pop_num)])

    if algorithm_name == 'DURM':
        algorithm = DURM(model)

    elif algorithm_name == 'BALD':
        algorithm = BALD(model)
    '''
    elif algorithm_name == 'MaxEnt':
        algorithm = Max_Ent(model)
    
    elif algorithm_name == 'VarRatio':
        algorithm = Variation_Ratios(model)

    elif algorithm_name == 'MeanStd' :
        algorithm = Mean_std(model)
    '''
    
    exp = Experiment_Realworld(algorithm, dim, model, num_t, MAP_0, nHess_0, R, P, Q, PQI)

    Data = exp.do(populate_idx)
    
    Data = np.array(Data)
    np.save("Realworld_" + model_name + "_" + str(dim) +"_" + algorithm_name + ".npy",Data)

# %%
'''
import numpy as np
from Utils import sigmoid, log_gaussian, MIRT, LN, Record, Belief, SIR
from Utils import DURM_LN, DURM_MIRT, Experiment_Synthetic, Run_Synthetic
from Utils import DURM, BALD, Experiment_Realworld, Run_RealWorld
'''

''' Synthetic Case Experiments '''
#'''
dim = 4
alpha = 10
model_name = 'LN'
true_theta = np.array([0.9, 0.3, 0.3, 0.1])
#true_theta = np.array([0, 0, 0, 0])
num_t = 500
MAP_0 = np.array([1.0, 0.0, 0.6, 1.0])
nHess_0 = np.array([
    [ 0.58396333, -0.36175317,  0.08181892, -0.01999662],
    [-0.36175317,  0.47667193,  0.02797142, -0.05730899],
    [ 0.08181892,  0.02797142,  0.2620719 ,  0.03275013],
    [-0.01999662, -0.05730899,  0.03275013,  0.27729285]
    ]) # Eigvals : 0.9, 0.3, 0.3, 0.1
iterations = 10

Run_Synthetic(model_name, dim, alpha, true_theta, num_t, MAP_0, nHess_0, iterations) 
#'''

''' Realworld Case Experiments '''
'''
algorithm_name = 'DURM'
model_name = 'MIRT'
dim = 4
pop_num = 30

Run_RealWorld(algorithm_name, model_name, dim, pop_num)
#'''
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/var/folders/kt/96t2gt_x6w9_qdjqgwbt74lw0000gn/T/ipykernel_8923/383916559.py:101: RuntimeWarning: divide by zero encountered in log
#   LL = lambda theta : np.log( self.f(theta, x).reshape(-1) if y==1 else 1-self.f(theta, x).reshape(-1) ) # Log Likelihood
# LN
# time step 1
# differential Entropy :
# 577.2230795906729
# approx differential Entropy :
# 8.079223131854478
# L2 norm :
# 1.0
# time step 2
# differential Entropy :
# 567.6097195064482
# approx differential Entropy :
# 8.074550591428086
# L2 norm :
# 1.0
# time step 3
# differential Entropy :
# 563.0512560152143
# approx differential Entropy :
# 8.069663131605322
# L2 norm :
# 1.0
# time step 4
# differential Entropy :
# 560.0912711723516
# approx differential Entropy :
# 8.064538926967037
# L2 norm :
# 1.0
# time step 5
# differential Entropy :
# 557.9278730205173
# approx differential Entropy :
# 8.059152690997735
# L2 norm :
# 1.0
# time step 6
# differential Entropy :
# 556.233358315136
# approx differential Entropy :
# 8.05347491410801
# L2 norm :
# 1.0
# time step 7
# differential Entropy :
# 554.8218897580106
# approx differential Entropy :
# 8.047470882688577
# L2 norm :
# 1.0
# time step 8
# differential Entropy :
# 553.5708557674245
# approx differential Entropy :
# 8.041099400083606
# L2 norm :
# 1.0
# time step 9
# differential Entropy :
# 552.4040691668581
# approx differential Entropy :
# 8.034311095312193
# L2 norm :
# 1.0
# time step 10
# differential Entropy :
# 551.2899261379844
# approx differential Entropy :
# 8.027046151577807
# L2 norm :
# 1.0
# time step 11
# differential Entropy :
# 550.2277316074296
# approx differential Entropy :
# 8.01923120215311
# L2 norm :
# 1.0
# time step 12
# differential Entropy :
# 549.2168688557476
# approx differential Entropy :
# 8.010775005232585
# L2 norm :
# 1.0
# time step 13
# differential Entropy :
# 548.2357562469635
# approx differential Entropy :
# 8.001562284008113
# L2 norm :
# 1.0
# time step 14
# differential Entropy :
# 547.260414161165
# approx differential Entropy :
# 7.99144473276775
# L2 norm :
# 1.0
# time step 15
# differential Entropy :
# 546.3007099017588
# approx differential Entropy :
# 7.980227506266574
# L2 norm :
# 1.0
# time step 16
# differential Entropy :
# 545.433342884196
# approx differential Entropy :
# 7.967648246671361
# L2 norm :
# 1.0
# time step 17
# differential Entropy :
# 544.8007723621473
# approx differential Entropy :
# 7.953343256623143
# L2 norm :
# 1.0
# time step 18
# differential Entropy :
# 544.3984243911516
# approx differential Entropy :
# 7.9367904261488045
# L2 norm :
# 1.0
# time step 19
# differential Entropy :
# 543.950786311741
# approx differential Entropy :
# 7.917207627775854
# L2 norm :
# 1.0
# time step 20
# differential Entropy :
# 543.2414786621148
# approx differential Entropy :
# 7.893359734502835
# L2 norm :
# 1.0
# time step 21
# differential Entropy :
# 542.4671185433853
# approx differential Entropy :
# 7.863161956151949
# L2 norm :
# 1.0
# time step 22
# differential Entropy :
# 541.6008815052079
# approx differential Entropy :
# 7.8227814722580735
# L2 norm :
# 1.0
# time step 23
# differential Entropy :
# 539.7403101927167
# approx differential Entropy :
# 7.7643485037508615
# L2 norm :
# 1.0
# time step 24
# differential Entropy :
# 529.6305053300722
# approx differential Entropy :
# 7.6693043108314365
# L2 norm :
# 1.0
# time step 25
# differential Entropy :
# 516.5171627232419
# approx differential Entropy :
# 7.48740039645325
# L2 norm :
# 1.0
# time step 26
# differential Entropy :
# 429.202430250025
# approx differential Entropy :
# 7.091419195349332
# L2 norm :
# 1.0
# time step 27
# differential Entropy :
# 239.2527266445853
# approx differential Entropy :
# 6.424568313832866
# L2 norm :
# 1.0
# time step 28
# differential Entropy :
# 139.45851274878817
# approx differential Entropy :
# 5.9113651460829795
# L2 norm :
# 1.0
# time step 29
# differential Entropy :
# 103.02557988906861
# approx differential Entropy :
# 5.624485931004672
# L2 norm :
# 1.0
# time step 30
# differential Entropy :
# 84.48447045179417
# approx differential Entropy :
# 5.436399257414716
# L2 norm :
# 1.0
# time step 31
# differential Entropy :
# 73.01871300536033
# approx differential Entropy :
# 5.297869853502363
# L2 norm :
# 1.0
# time step 32
# differential Entropy :
# 65.09914010112819
# approx differential Entropy :
# 5.188576805128554
# L2 norm :
# 1.0
# time step 33
# differential Entropy :
# 59.23188577890097
# approx differential Entropy :
# 5.098457703059408
# L2 norm :
# 1.0
# time step 34
# differential Entropy :
# 54.67058011865984
# approx differential Entropy :
# 5.021846809330738
# L2 norm :
# 1.0
# time step 35
# differential Entropy :
# 50.99791488485399
# approx differential Entropy :
# 4.955252389288642
# L2 norm :
# 1.0
# time step 36
# differential Entropy :
# 47.960873093959826
# approx differential Entropy :
# 4.896375176906689
# L2 norm :
# 1.0
# time step 37
# differential Entropy :
# 45.39637098570953
# approx differential Entropy :
# 4.843622776419969
# L2 norm :
# 1.0
# time step 38
# differential Entropy :
# 43.194135544502934
# approx differential Entropy :
# 4.79584772564078
# L2 norm :
# 1.0
# time step 39
# differential Entropy :
# 41.276673226762455
# approx differential Entropy :
# 4.752196310414828
# L2 norm :
# 1.0
# time step 40
# differential Entropy :
# 39.58777216902727
# approx differential Entropy :
# 4.712016429423594
# L2 norm :
# 1.0
# time step 41
# differential Entropy :
# 38.08556144613387
# approx differential Entropy :
# 4.674798886183568
# L2 norm :
# 1.0
# time step 42
# differential Entropy :
# 36.738141732288575
# approx differential Entropy :
# 4.6401385625619405
# L2 norm :
# 1.0
# time step 43
# differential Entropy :
# 35.520735321764526
# approx differential Entropy :
# 4.607707918433155
# L2 norm :
# 1.0
# time step 44
# differential Entropy :
# 34.41376971628284
# approx differential Entropy :
# 4.577238408253272
# L2 norm :
# 1.0
# time step 45
# differential Entropy :
# 33.401554488602144
# approx differential Entropy :
# 4.548507139859119
# L2 norm :
# 1.0
# time step 46
# differential Entropy :
# 32.47134638234485
# approx differential Entropy :
# 4.521327097751932
# L2 norm :
# 1.0
# time step 47
# differential Entropy :
# 31.61267509638602
# approx differential Entropy :
# 4.495539847240263
# L2 norm :
# 1.0
# time step 48
# differential Entropy :
# 30.81684814513309
# approx differential Entropy :
# 4.4710100012687874
# L2 norm :
# 1.0
# time step 49
# differential Entropy :
# 30.076581261310842
# approx differential Entropy :
# 4.447620962939654
# L2 norm :
# 1.0
# time step 50
# differential Entropy :
# 29.3857184339884
# approx differential Entropy :
# 4.425271606667468
# L2 norm :
# 1.0
# time step 51
# differential Entropy :
# 28.739017008881135
# approx differential Entropy :
# 4.403873660345395
# L2 norm :
# 1.0
# time step 52
# differential Entropy :
# 28.131980726659588
# approx differential Entropy :
# 4.383349618189798
# L2 norm :
# 1.0
# time step 53
# differential Entropy :
# 27.5607285670295
# approx differential Entropy :
# 4.363631060303267
# L2 norm :
# 1.0
# time step 54
# differential Entropy :
# 27.02189067383651
# approx differential Entropy :
# 4.3446572874888965
# L2 norm :
# 1.0
# time step 55
# differential Entropy :
# 26.51252499742105
# approx differential Entropy :
# 4.326374202964703
# L2 norm :
# 1.0
# time step 56
# differential Entropy :
# 26.030049955475107
# approx differential Entropy :
# 4.308733389302824
# L2 norm :
# 1.0
# time step 57
# differential Entropy :
# 25.572189600202964
# approx differential Entropy :
# 4.291691341103737
# L2 norm :
# 1.0
# time step 58
# differential Entropy :
# 25.136928638659892
# approx differential Entropy :
# 4.27520882292496
# L2 norm :
# 1.0
# time step 59
# differential Entropy :
# 24.722475281963465
# approx differential Entropy :
# 4.2592503287210235
# L2 norm :
# 1.0
# time step 60
# differential Entropy :
# 24.32723036344397
# approx differential Entropy :
# 4.243783624137596
# L2 norm :
# 1.0
# time step 61
# differential Entropy :
# 23.94976151364088
# approx differential Entropy :
# 4.228779356883163
# L2 norm :
# 1.0
# time step 62
# differential Entropy :
# 23.588781442765555
# approx differential Entropy :
# 4.214210723385261
# L2 norm :
# 1.0
# time step 63
# differential Entropy :
# 23.243129580643867
# approx differential Entropy :
# 4.200053182254235
# L2 norm :
# 1.0
# time step 64
# differential Entropy :
# 22.911756477864547
# approx differential Entropy :
# 4.186284206886709
# L2 norm :
# 1.0
# time step 65
# differential Entropy :
# 22.593710490802984
# approx differential Entropy :
# 4.1728830709675595
# L2 norm :
# 1.0
# time step 66
# differential Entropy :
# 22.28812636564702
# approx differential Entropy :
# 4.1598306617589635
# L2 norm :
# 1.0
# time step 67
# differential Entropy :
# 21.994215409815364
# approx differential Entropy :
# 4.14710931696863
# L2 norm :
# 1.0
# time step 68
# differential Entropy :
# 21.71125699615639
# approx differential Entropy :
# 4.134702681713186
# L2 norm :
# 1.0
# time step 69
# differential Entropy :
# 21.43859119187664
# approx differential Entropy :
# 4.122595582679669
# L2 norm :
# 1.0
# time step 70
# differential Entropy :
# 21.17561234012101
# approx differential Entropy :
# 4.110773917062517
# L2 norm :
# 1.0
# time step 71
# differential Entropy :
# 20.921763452268866
# approx differential Entropy :
# 4.099224554243397
# L2 norm :
# 1.0
# time step 72
# differential Entropy :
# 20.676531292625032
# approx differential Entropy :
# 4.087935248499457
# L2 norm :
# 1.0
# time step 73
# differential Entropy :
# 20.4394420565181
# approx differential Entropy :
# 4.076894561288594
# L2 norm :
# 1.0
# time step 74
# differential Entropy :
# 20.210057559430986
# approx differential Entropy :
# 4.06609179187863
# L2 norm :
# 1.0
# time step 75
# differential Entropy :
# 19.98797186657051
# approx differential Entropy :
# 4.055516915268393
# L2 norm :
# 1.0
# time step 76
# differential Entropy :
# 19.772808304644283
# approx differential Entropy :
# 4.045160526500064
# L2 norm :
# 1.0
# time step 77
# differential Entropy :
# 19.564216805111528
# approx differential Entropy :
# 4.035013790589914
# L2 norm :
# 1.0
# time step 78
# differential Entropy :
# 19.361871536687595
# approx differential Entropy :
# 4.025068397410252
# L2 norm :
# 1.0
# time step 79
# differential Entropy :
# 19.165468790339382
# approx differential Entropy :
# 4.015316520947359
# L2 norm :
# 1.0
# time step 80
# differential Entropy :
# 18.97472508569774
# approx differential Entropy :
# 4.0057507824351966
# L2 norm :
# 1.0
# time step 81
# differential Entropy :
# 18.789375471938815
# approx differential Entropy :
# 3.996364216931906
# L2 norm :
# 1.0
# time step 82
# differential Entropy :
# 18.60917200000128
# approx differential Entropy :
# 3.9871502429594035
# L2 norm :
# 1.0
# time step 83
# differential Entropy :
# 18.43388234585292
# approx differential Entropy :
# 3.978102634876164
# L2 norm :
# 1.0
# time step 84
# differential Entropy :
# 18.263288567979334
# approx differential Entropy :
# 3.969215497692987
# L2 norm :
# 1.0
# time step 85
# differential Entropy :
# 18.09718598337012
# approx differential Entropy :
# 3.960483244077089
# L2 norm :
# 1.0
# time step 86
# differential Entropy :
# 17.935382148988072
# approx differential Entropy :
# 3.951900573320221
# L2 norm :
# 1.0
# time step 87
# differential Entropy :
# 17.77769593748433
# approx differential Entropy :
# 3.943462452073399
# L2 norm :
# 1.0
# time step 88
# differential Entropy :
# 17.623956696717443
# approx differential Entropy :
# 3.9351640966725423
# L2 norm :
# 1.0
# time step 89
# differential Entropy :
# 17.4740034844409
# approx differential Entropy :
# 3.9270009569006152
# L2 norm :
# 1.0
# time step 90
# differential Entropy :
# 17.327684370001773
# approx differential Entropy :
# 3.9189687010478167
# L2 norm :
# 1.0
# time step 91
# differential Entropy :
# 17.184855796803713
# approx differential Entropy :
# 3.9110632021479628
# L2 norm :
# 1.0
# time step 92
# differential Entropy :
# 17.045381998825167
# approx differential Entropy :
# 3.903280525281156
# L2 norm :
# 1.0
# time step 93
# differential Entropy :
# 16.90913446605968
# approx differential Entropy :
# 3.895616915845486
# L2 norm :
# 1.0
# time step 94
# differential Entropy :
# 16.775991454300417
# approx differential Entropy :
# 3.888068788710144
# L2 norm :
# 1.0
# time step 95
# differential Entropy :
# 16.645837534473575
# approx differential Entropy :
# 3.8806327181719746
# L2 norm :
# 1.0
# time step 96
# differential Entropy :
# 16.518563178506763
# approx differential Entropy :
# 3.8733054286444935
# L2 norm :
# 1.0
# time step 97
# differential Entropy :
# 16.394064377600035
# approx differential Entropy :
# 3.86608378601735
# L2 norm :
# 1.0
# time step 98
# differential Entropy :
# 16.27224229042727
# approx differential Entropy :
# 3.8589647896276613
# L2 norm :
# 1.0
# time step 99
# differential Entropy :
# 16.153002918143585
# approx differential Entropy :
# 3.8519455647932053
# L2 norm :
# 1.0
# time step 100
# differential Entropy :
# 16.03625680438165
# approx differential Entropy :
# 3.8450233558602096
# L2 norm :
# 1.0
# time step 101
# differential Entropy :
# 15.921918757145521
# approx differential Entropy :
# 3.8381955197244384
# L2 norm :
# 1.0
# time step 102
# differential Entropy :
# 15.809907591745059
# approx differential Entropy :
# 3.8314595197864474
# L2 norm :
# 1.0
# time step 103
# differential Entropy :
# 15.700145891930006
# approx differential Entropy :
# 3.824812920307587
# L2 norm :
# 1.0
# time step 104
# differential Entropy :
# 15.592559788595283
# approx differential Entropy :
# 3.818253381134838
# L2 norm :
# 1.0
# time step 105
# differential Entropy :
# 15.487078753966925
# approx differential Entropy :
# 3.811778652765816
# L2 norm :
# 1.0
# time step 106
# differential Entropy :
# 15.38363540995414
# approx differential Entropy :
# 3.805386571727853
# L2 norm :
# 1.0
# time step 107
# differential Entropy :
# 0.021526056577734633
# approx differential Entropy :
# 3.7990750562485793
# L2 norm :
# 1.0
# time step 108
# differential Entropy :
# 0.021208419169962637
# approx differential Entropy :
# 3.7928421021943333
# L2 norm :
# 1.0
# time step 109
# differential Entropy :
# 0.020899314060215352
# approx differential Entropy :
# 3.7866857792587467
# L2 norm :
# 1.0
# time step 110
# differential Entropy :
# 0.020598409628387198
# approx differential Entropy :
# 3.780604227381631
# L2 norm :
# 1.0
# time step 111
# differential Entropy :
# 0.020305390673423948
# approx differential Entropy :
# 3.7745956533823413
# L2 norm :
# 1.0
# time step 112
# differential Entropy :
# 0.020019957437779734
# approx differential Entropy :
# 3.768658327792994
# L2 norm :
# 1.0
# time step 113
# differential Entropy :
# 0.019741824699507016
# approx differential Entropy :
# 3.7627905818764424
# L2 norm :
# 1.0
# time step 114
# differential Entropy :
# 0.019470720926757227
# approx differential Entropy :
# 3.756990804816475
# L2 norm :
# 1.0
# time step 115
# differential Entropy :
# 0.019206387489657424
# approx differential Entropy :
# 3.7512574410691015
# L2 norm :
# 1.0
# time step 116
# differential Entropy :
# 0.018948577924755843
# approx differential Entropy :
# 3.7455889878629955
# L2 norm :
# 1.0
# time step 117
# differential Entropy :
# 0.01869705724859076
# approx differential Entropy :
# 3.7399839928400387
# L2 norm :
# 1.0
# time step 118
# differential Entropy :
# 0.018451601316370414
# approx differential Entropy :
# 3.7344410518261
# L2 norm :
# 1.0
# time step 119
# differential Entropy :
# 0.018211996222114883
# approx differential Entropy :
# 3.7289588067233366
# L2 norm :
# 1.0
# time step 120
# differential Entropy :
# 0.017978037737620578
# approx differential Entropy :
# 3.7235359435168447
# L2 norm :
# 1.0
# time step 121
# differential Entropy :
# 0.017749530786977843
# approx differential Entropy :
# 3.7181711903880137
# L2 norm :
# 1.0
# time step 122
# differential Entropy :
# 0.01752628895452227
# approx differential Entropy :
# 3.712863315927256
# L2 norm :
# 1.0
# time step 123
# differential Entropy :
# 0.0173081340231855
# approx differential Entropy :
# 3.7076111274407673
# L2 norm :
# 1.0
# time step 124
# differential Entropy :
# 0.017094895541718908
# approx differential Entropy :
# 3.7024134693447865
# L2 norm :
# 1.0
# time step 125
# differential Entropy :
# 0.01688641041820541
# approx differential Entropy :
# 3.697269221642454
# L2 norm :
# 1.0
# time step 126
# differential Entropy :
# 0.016682522538598622
# approx differential Entropy :
# 3.692177298477442
# L2 norm :
# 1.0
# time step 127
# differential Entropy :
# 0.016483082407695193
# approx differential Entropy :
# 3.687136646761477
# L2 norm :
# 1.0
# time step 128
# differential Entropy :
# 0.01628794681211903
# approx differential Entropy :
# 3.682146244868782
# L2 norm :
# 1.0
# time step 129
# differential Entropy :
# 0.01609697850272651
# approx differential Entropy :
# 3.677205101395602
# L2 norm :
# 1.0
# time step 130
# differential Entropy :
# 0.015910045896068058
# approx differential Entropy :
# 3.6723122539801825
# L2 norm :
# 1.0
# time step 131
# differential Entropy :
# 0.015727022792617652
# approx differential Entropy :
# 3.6674667681800086
# L2 norm :
# 1.0
# time step 132
# differential Entropy :
# 0.015547788112068748
# approx differential Entropy :
# 3.662667736401957
# L2 norm :
# 1.0
# time step 133
# differential Entropy :
# 0.01537222564271128
# approx differential Entropy :
# 3.657914276884127
# L2 norm :
# 1.0
# time step 134
# differential Entropy :
# 0.015200223806038948
# approx differential Entropy :
# 3.653205532724984
# L2 norm :
# 1.0
# time step 135
# differential Entropy :
# 0.015031675433790425
# approx differential Entropy :
# 3.6485406709575816
# L2 norm :
# 1.0
# time step 136
# differential Entropy :
# 0.014866477557809532
# approx differential Entropy :
# 3.6439188816669743
# L2 norm :
# 1.0
# time step 137
# differential Entropy :
# 0.014704531211487895
# approx differential Entropy :
# 3.639339377147234
# L2 norm :
# 1.0
# time step 138
# differential Entropy :
# 0.014545741241889074
# approx differential Entropy :
# 3.634801391097487
# L2 norm :
# 1.0
# time step 139
# differential Entropy :
# 0.014390016132383401
# approx differential Entropy :
# 3.630304177852984
# L2 norm :
# 1.0
# time step 140
# differential Entropy :
# 0.014237267834625006
# approx differential Entropy :
# 3.6258470116515014
# L2 norm :
# 1.0
# time step 141
# differential Entropy :
# 0.01408741160966891
# approx differential Entropy :
# 3.6214291859309435
# L2 norm :
# 1.0
# time step 142
# differential Entropy :
# 0.013940365877452258
# approx differential Entropy :
# 3.617050012658538
# L2 norm :
# 1.0
# time step 143
# differential Entropy :
# 0.01379605207422224
# approx differential Entropy :
# 3.612708821688665
# L2 norm :
# 1.0
# time step 144
# differential Entropy :
# 0.013654394517445044
# approx differential Entropy :
# 3.6084049601481527
# L2 norm :
# 1.0
# time step 145
# differential Entropy :
# 0.013515320277815407
# approx differential Entropy :
# 3.6041377918480273
# L2 norm :
# 1.0
# time step 146
# differential Entropy :
# 0.013378759057730307
# approx differential Entropy :
# 3.5999066967200952
# L2 norm :
# 1.0
# time step 147
# differential Entropy :
# 0.013244643076056856
# approx differential Entropy :
# 3.5957110702764683
# L2 norm :
# 1.0
# time step 148
# differential Entropy :
# 0.013112906958709583
# approx differential Entropy :
# 3.5915503230928905
# L2 norm :
# 1.0
# time step 149
# differential Entropy :
# 0.012983487634930568
# approx differential Entropy :
# 3.5874238803115484
# L2 norm :
# 1.0
# time step 150
# differential Entropy :
# 0.012856324238395252
# approx differential Entropy :
# 3.583331181165966
# L2 norm :
# 1.0
# time step 151
# differential Entropy :
# 0.012731358013765437
# approx differential Entropy :
# 3.5792716785236047
# L2 norm :
# 1.0
# time step 152
# differential Entropy :
# 0.012608532227386436
# approx differential Entropy :
# 3.5752448384481945
# L2 norm :
# 1.0
# time step 153
# differential Entropy :
# 0.012487792082469128
# approx differential Entropy :
# 3.571250139778141
# L2 norm :
# 1.0
# time step 154
# differential Entropy :
# 0.012369084638764757
# approx differential Entropy :
# 3.567287073722848
# L2 norm :
# 1.0
# time step 155
# differential Entropy :
# 0.012252358735612456
# approx differential Entropy :
# 3.5633551434742072
# L2 norm :
# 1.0
# time step 156
# differential Entropy :
# 0.012137564918990106
# approx differential Entropy :
# 3.5594538638333075
# L2 norm :
# 1.0
# time step 157
# differential Entropy :
# 0.012024655372056124
# approx differential Entropy :
# 3.5555827608514448
# L2 norm :
# 1.0
# time step 158
# differential Entropy :
# 0.011913583848816212
# approx differential Entropy :
# 3.5517413714855075
# L2 norm :
# 1.0
# time step 159
# differential Entropy :
# 0.011804305611098551
# approx differential Entropy :
# 3.5479292432657137
# L2 norm :
# 1.0
# time step 160
# differential Entropy :
# 0.011696777368330998
# approx differential Entropy :
# 3.544145933975997
# L2 norm :
# 1.0
# time step 161
# differential Entropy :
# 0.01159095722015493
# approx differential Entropy :
# 3.540391011346884
# L2 norm :
# 1.0
# time step 162
# differential Entropy :
# 0.011486804601865732
# approx differential Entropy :
# 3.5366640527596904
# L2 norm :
# 1.0
# time step 163
# differential Entropy :
# 0.011384280232078261
# approx differential Entropy :
# 3.532964644960798
# L2 norm :
# 1.0
# time step 164
# differential Entropy :
# 0.01128334606296446
# approx differential Entropy :
# 3.5292923837875168
# L2 norm :
# 1.0
# time step 165
# differential Entropy :
# 0.011183965232630877
# approx differential Entropy :
# 3.525646873903107
# L2 norm :
# 1.0
# time step 166
# differential Entropy :
# 0.011086102019800965
# approx differential Entropy :
# 3.5220277285423425
# L2 norm :
# 1.0
# time step 167
# differential Entropy :
# 0.010989721800342678
# approx differential Entropy :
# 3.5184345692646235
# L2 norm :
# 1.0
# time step 168
# differential Entropy :
# 0.010894791005818798
# approx differential Entropy :
# 3.5148670257176686
# L2 norm :
# 1.0
# time step 169
# differential Entropy :
# 0.010801277084043822
# approx differential Entropy :
# 3.5113247354080634
# L2 norm :
# 1.0
# time step 170
# differential Entropy :
# 0.010709148460813302
# approx differential Entropy :
# 3.5078073434810246
# L2 norm :
# 1.0
# time step 171
# differential Entropy :
# 0.010618374504046683
# approx differential Entropy :
# 3.5043145025068747
# L2 norm :
# 1.0
# time step 172
# differential Entropy :
# 0.010528925488968336
# approx differential Entropy :
# 3.500845872275683
# L2 norm :
# 1.0
# time step 173
# differential Entropy :
# 0.010440772564871725
# approx differential Entropy :
# 3.4974011195985772
# L2 norm :
# 1.0
# time step 174
# differential Entropy :
# 0.010353887723537701
# approx differential Entropy :
# 3.4939799181158024
# L2 norm :
# 1.0
# time step 175
# differential Entropy :
# 0.01026824376871852
# approx differential Entropy :
# 3.490581948111516
# L2 norm :
# 1.0
# time step 176
# differential Entropy :
# 0.010183814286988944
# approx differential Entropy :
# 3.487206896334585
# L2 norm :
# 1.0
# time step 177
# differential Entropy :
# 0.010100573620097825
# approx differential Entropy :
# 3.4838544558256253
# L2 norm :
# 1.0
# time step 178
# differential Entropy :
# 0.01001849683787805
# approx differential Entropy :
# 3.480524325749463
# L2 norm :
# 1.0
# time step 179
# differential Entropy :
# 0.009937559713006075
# approx differential Entropy :
# 3.4772162112336673
# L2 norm :
# 1.0
# time step 180
# differential Entropy :
# 0.009857738696219585
# approx differential Entropy :
# 3.473929823211618
# L2 norm :
# 1.0
# time step 181
# differential Entropy :
# 0.00977901089280378
# approx differential Entropy :
# 3.470664878271349
# L2 norm :
# 1.0
# time step 182
# differential Entropy :
# 0.00970135404009906
# approx differential Entropy :
# 3.46742109850925
# L2 norm :
# 1.0
# time step 183
# differential Entropy :
# 0.009624746485801665
# approx differential Entropy :
# 3.4641982113876724
# L2 norm :
# 1.0
# time step 184
# differential Entropy :
# 0.009549167167061487
# approx differential Entropy :
# 3.4609959495982654
# L2 norm :
# 1.0
# time step 185
# differential Entropy :
# 0.009474595590758302
# approx differential Entropy :
# 3.4578140509289144
# L2 norm :
# 1.0
# time step 186
# differential Entropy :
# 0.00940101181400647
# approx differential Entropy :
# 3.45465225813482
# L2 norm :
# 1.0
# time step 187
# differential Entropy :
# 0.009328396426127388
# approx differential Entropy :
# 3.4515103188141896
# L2 norm :
# 1.0
# time step 188
# differential Entropy :
# 0.00925673053065335
# approx differential Entropy :
# 3.4483879852868986
# L2 norm :
# 1.0
# time step 189
# differential Entropy :
# 0.009185995728554075
# approx differential Entropy :
# 3.445285014478313
# L2 norm :
# 1.0
# time step 190
# differential Entropy :
# 0.0091161741018203
# approx differential Entropy :
# 3.442201167804875
# L2 norm :
# 1.0
# time step 191
# differential Entropy :
# 0.009047248197814306
# approx differential Entropy :
# 3.4391362110650245
# L2 norm :
# 1.0
# time step 192
# differential Entropy :
# 0.008979201014071138
# approx differential Entropy :
# 3.4360899143319004
# L2 norm :
# 1.0
# time step 193
# differential Entropy :
# 0.008912015984001232
# approx differential Entropy :
# 3.433062051850445
# L2 norm :
# 1.0
# time step 194
# differential Entropy :
# 0.008845676962719167
# approx differential Entropy :
# 3.430052401936746
# L2 norm :
# 1.0
# time step 195
# differential Entropy :
# 0.008780168213753804
# approx differential Entropy :
# 3.4270607468809144
# L2 norm :
# 1.0
# time step 196
# differential Entropy :
# 0.008715474396133769
# approx differential Entropy :
# 3.424086872852795
# L2 norm :
# 1.0
# time step 197
# differential Entropy :
# 0.008651580551803303
# approx differential Entropy :
# 3.4211305698099577
# L2 norm :
# 1.0
# time step 198
# differential Entropy :
# 0.008588472093818708
# approx differential Entropy :
# 3.418191631409192
# L2 norm :
# 1.0
# time step 199
# differential Entropy :
# 0.008526134794722685
# approx differential Entropy :
# 3.4152698549199263
# L2 norm :
# 1.0
# time step 200
# differential Entropy :
# 0.008464554775483423
# approx differential Entropy :
# 3.412365041140597
# L2 norm :
# 1.0
# time step 201
# differential Entropy :
# 0.008403718494771098
# approx differential Entropy :
# 3.4094769943170067
# L2 norm :
# 1.0
# time step 202
# differential Entropy :
# 0.008343612738656582
# approx differential Entropy :
# 3.4066055220631166
# L2 norm :
# 1.0
# time step 203
# differential Entropy :
# 0.008284224610624882
# approx differential Entropy :
# 3.4037504352849677
# L2 norm :
# 1.0
# time step 204
# differential Entropy :
# 0.008225541522170981
# approx differential Entropy :
# 3.4009115481049683
# L2 norm :
# 1.0
# time step 205
# differential Entropy :
# 0.008167551183276589
# approx differential Entropy :
# 3.3980886777901755
# L2 norm :
# 1.0
# time step 206
# differential Entropy :
# 0.008110241593789539
# approx differential Entropy :
# 3.395281644681468
# L2 norm :
# 1.0
# time step 207
# differential Entropy :
# 0.0080536010346853
# approx differential Entropy :
# 3.392490272124901
# L2 norm :
# 1.0
# time step 208
# differential Entropy :
# 0.00799761805978127
# approx differential Entropy :
# 3.3897143864054713
# L2 norm :
# 1.0
# time step 209
# differential Entropy :
# 0.007942281487818862
# approx differential Entropy :
# 3.386953816681582
# L2 norm :
# 1.0
# time step 210
# differential Entropy :
# 0.007887580394665231
# approx differential Entropy :
# 3.3842083949228257
# L2 norm :
# 1.0
# time step 211
# differential Entropy :
# 0.007833504105885477
# approx differential Entropy :
# 3.381477955848073
# L2 norm :
# 1.0
# time step 212
# differential Entropy :
# 0.007780042189592072
# approx differential Entropy :
# 3.3787623368660897
# L2 norm :
# 1.0
# time step 213
# differential Entropy :
# 0.007727184449463126
# approx differential Entropy :
# 3.3760613780177113
# L2 norm :
# 1.0
# time step 214
# differential Entropy :
# 0.007674920918023794
# approx differential Entropy :
# 3.373374921918627
# L2 norm :
# 1.0
# time step 215
# differential Entropy :
# 0.007623241850216921
# approx differential Entropy :
# 3.3707028137051314
# L2 norm :
# 1.0
# time step 216
# differential Entropy :
# 0.007572137717074469
# approx differential Entropy :
# 3.368044900980167
# L2 norm :
# 1.0
# time step 217
# differential Entropy :
# 0.00752159919971532
# approx differential Entropy :
# 3.3654010337617053
# L2 norm :
# 1.0
# time step 218
# differential Entropy :
# 0.007471617183457179
# approx differential Entropy :
# 3.362771064431494
# L2 norm :
# 1.0
# time step 219
# differential Entropy :
# 0.0074221827522352015
# approx differential Entropy :
# 3.3601548476856973
# L2 norm :
# 1.0
# time step 220
# differential Entropy :
# 0.007373287183095725
# approx differential Entropy :
# 3.357552240487076
# L2 norm :
# 1.0
# time step 221
# differential Entropy :
# 0.007324921940845257
# approx differential Entropy :
# 3.354963102017969
# L2 norm :
# 1.0
# time step 222
# differential Entropy :
# 0.007277078672976243
# approx differential Entropy :
# 3.3523872936345156
# L2 norm :
# 1.0
# time step 223
# differential Entropy :
# 0.007229749204915149
# approx differential Entropy :
# 3.3498246788219617
# L2 norm :
# 1.0
# time step 224
# differential Entropy :
# 0.007182925534817621
# approx differential Entropy :
# 3.3472751231523246
# L2 norm :
# 1.0
# time step 225
# differential Entropy :
# 0.007136599829332228
# approx differential Entropy :
# 3.3447384942402882
# L2 norm :
# 1.0
# time step 226
# differential Entropy :
# 0.007090764418933122
# approx differential Entropy :
# 3.342214661703848
# L2 norm :
# 1.0
# time step 227
# differential Entropy :
# 0.007045411793577994
# approx differential Entropy :
# 3.3397034971228496
# L2 norm :
# 1.0
# time step 228
# differential Entropy :
# 0.007000534598626844
# approx differential Entropy :
# 3.3372048740002653
# L2 norm :
# 1.0
# time step 229
# differential Entropy :
# 0.0069561256305597655
# approx differential Entropy :
# 3.3347186677245353
# L2 norm :
# 1.0
# time step 230
# differential Entropy :
# 0.006912177833252554
# approx differential Entropy :
# 3.3322447555311525
# L2 norm :
# 1.0
# time step 231
# differential Entropy :
# 0.006868684294032505
# approx differential Entropy :
# 3.3297830164672066
# L2 norm :
# 1.0
# time step 232
# differential Entropy :
# 0.006825638240006685
# approx differential Entropy :
# 3.327333331355793
# L2 norm :
# 1.0
# time step 233
# differential Entropy :
# 0.0067830330345106426
# approx differential Entropy :
# 3.324895582760912
# L2 norm :
# 1.0
# time step 234
# differential Entropy :
# 0.0067408621735762396
# approx differential Entropy :
# 3.3224696549544173
# L2 norm :
# 1.0
# time step 235
# differential Entropy :
# 0.006699119282619165
# approx differential Entropy :
# 3.3200554338828896
# L2 norm :
# 1.0
# time step 236
# differential Entropy :
# 0.006657798113157216
# approx differential Entropy :
# 3.317652807134757
# L2 norm :
# 1.0
# time step 237
# differential Entropy :
# 0.006616892539608306
# approx differential Entropy :
# 3.315261663910139
# L2 norm :
# 1.0
# time step 238
# differential Entropy :
# 0.006576396556256202
# approx differential Entropy :
# 3.3128818949891734
# L2 norm :
# 1.0
# time step 239
# differential Entropy :
# 0.006536304274283719
# approx differential Entropy :
# 3.3105133927027914
# L2 norm :
# 1.0
# time step 240
# differential Entropy :
# 0.006496609918816608
# approx differential Entropy :
# 3.3081560509031047
# L2 norm :
# 1.0
# time step 241
# differential Entropy :
# 0.006457307826284137
# approx differential Entropy :
# 3.3058097649350913
# L2 norm :
# 1.0
# time step 242
# differential Entropy :
# 0.006418392441476759
# approx differential Entropy :
# 3.3034744316082647
# L2 norm :
# 1.0
# time step 243
# differential Entropy :
# 0.006379858315078402
# approx differential Entropy :
# 3.3011499491707283
# L2 norm :
# 1.0
# time step 244
# differential Entropy :
# 0.006341700100970492
# approx differential Entropy :
# 3.2988362172806927
# L2 norm :
# 1.0
# time step 245
# differential Entropy :
# 0.0063039125539211295
# approx differential Entropy :
# 3.2965331369821076
# L2 norm :
# 1.0
# time step 246
# differential Entropy :
# 0.0062664905269487325
# approx differential Entropy :
# 3.294240610678946
# L2 norm :
# 1.0
# time step 247
# differential Entropy :
# 0.006229428969225338
# approx differential Entropy :
# 3.2919585421096373
# L2 norm :
# 1.0
# time step 248
# differential Entropy :
# 0.006192722923594493
# approx differential Entropy :
# 3.2896868363237033
# L2 norm :
# 1.0
# time step 249
# differential Entropy :
# 0.006156367524441909
# approx differential Entropy :
# 3.287425399657578
# L2 norm :
# 1.0
# time step 250
# differential Entropy :
# 0.006120357995542331
# approx differential Entropy :
# 3.2851741397116365
# L2 norm :
# 1.0
# time step 251
# differential Entropy :
# 0.006084689647928594
# approx differential Entropy :
# 3.282932965327647
# L2 norm :
# 1.0
# time step 252
# differential Entropy :
# 0.0060493578780011934
# approx differential Entropy :
# 3.280701786566664
# L2 norm :
# 1.0
# time step 253
# differential Entropy :
# 0.00601435816537611
# approx differential Entropy :
# 3.278480514686789
# L2 norm :
# 1.0
# time step 254
# differential Entropy :
# 0.005979686071052484
# approx differential Entropy :
# 3.276269062123018
# L2 norm :
# 1.0
# time step 255
# differential Entropy :
# 0.005945337235605839
# approx differential Entropy :
# 3.274067342465558
# L2 norm :
# 1.0
# time step 256
# differential Entropy :
# 0.005911307377254824
# approx differential Entropy :
# 3.271875270439947
# L2 norm :
# 1.0
# time step 257
# differential Entropy :
# 0.005877592290188493
# approx differential Entropy :
# 3.2696927618880953
# L2 norm :
# 1.0
# time step 258
# differential Entropy :
# 0.005844187842830889
# approx differential Entropy :
# 3.2675197337472657
# L2 norm :
# 1.0
# time step 259
# differential Entropy :
# 0.005811089976132417
# approx differential Entropy :
# 3.2653561040326373
# L2 norm :
# 1.0
# time step 260
# differential Entropy :
# 0.005778294702057747
# approx differential Entropy :
# 3.263201791817797
# L2 norm :
# 1.0
# time step 261
# differential Entropy :
# 0.005745798101857241
# approx differential Entropy :
# 3.261056717216785
# L2 norm :
# 1.0
# time step 262
# differential Entropy :
# 0.0057135963246780054
# approx differential Entropy :
# 3.258920801366725
# L2 norm :
# 1.0
# time step 263
# differential Entropy :
# 0.005681685585948697
# approx differential Entropy :
# 3.2567939664102927
# L2 norm :
# 1.0
# time step 264
# differential Entropy :
# 0.0056500621660360035
# approx differential Entropy :
# 3.2546761354780878
# L2 norm :
# 1.0
# time step 265
# differential Entropy :
# 0.005618722408692578
# approx differential Entropy :
# 3.2525672326731776
# L2 norm :
# 1.0
# time step 266
# differential Entropy :
# 0.005587662719869509
# approx differential Entropy :
# 3.250467183053158
# L2 norm :
# 1.0
# time step 267
# differential Entropy :
# 0.005556879566165182
# approx differential Entropy :
# 3.2483759126162117
# L2 norm :
# 1.0
# time step 268
# differential Entropy :
# 0.005526369473748997
# approx differential Entropy :
# 3.2462933482832823
# L2 norm :
# 1.0
# time step 269
# differential Entropy :
# 0.0054961290268104295
# approx differential Entropy :
# 3.244219417884601
# L2 norm :
# 1.0
# time step 270
# differential Entropy :
# 0.0054661548665302226
# approx differential Entropy :
# 3.242154050143794
# L2 norm :
# 1.0
# time step 271
# differential Entropy :
# 0.005436443689920573
# approx differential Entropy :
# 3.240097174663079
# L2 norm :
# 1.0
# time step 272
# differential Entropy :
# 0.005406992248354729
# approx differential Entropy :
# 3.2380487219092133
# L2 norm :
# 1.0
# time step 273
# differential Entropy :
# 0.005377797346755424
# approx differential Entropy :
# 3.236008623199549
# L2 norm :
# 1.0
# time step 274
# differential Entropy :
# 0.005348855842292439
# approx differential Entropy :
# 3.233976810688009
# L2 norm :
# 1.0
# time step 275
# differential Entropy :
# 0.005320164643319068
# approx differential Entropy :
# 3.2319532173509717
# L2 norm :
# 1.0
# time step 276
# differential Entropy :
# 0.005291720708331913
# approx differential Entropy :
# 3.229937776975536
# L2 norm :
# 1.0
# time step 277
# differential Entropy :
# 0.005263521044921974
# approx differential Entropy :
# 3.2279304241447786
# L2 norm :
# 1.0
# time step 278
# differential Entropy :
# 0.005235562708812852
# approx differential Entropy :
# 3.2259310942259627
# L2 norm :
# 1.0
# time step 279
# differential Entropy :
# 0.005207842802862771
# approx differential Entropy :
# 3.2239397233585434
# L2 norm :
# 1.0
# time step 280
# differential Entropy :
# 0.005180358476030851
# approx differential Entropy :
# 3.221956248440393
# L2 norm :
# 1.0
# time step 281
# differential Entropy :
# 0.005153106922476721
# approx differential Entropy :
# 3.2199806071174653
# L2 norm :
# 1.0
# time step 282
# differential Entropy :
# 0.005126085380791582
# approx differential Entropy :
# 3.2180127377709415
# L2 norm :
# 1.0
# time step 283
# differential Entropy :
# 0.0050992911328479745
# approx differential Entropy :
# 3.2160525795060746
# L2 norm :
# 1.0
# time step 284
# differential Entropy :
# 0.005072721503194823
# approx differential Entropy :
# 3.2141000721412487
# L2 norm :
# 1.0
# time step 285
# differential Entropy :
# 0.005046373858010399
# approx differential Entropy :
# 3.212155156196287
# L2 norm :
# 1.0
# time step 286
# differential Entropy :
# 0.00502024560434933
# approx differential Entropy :
# 3.2102177728817036
# L2 norm :
# 1.0
# time step 287
# differential Entropy :
# 0.0049943341894077955
# approx differential Entropy :
# 3.2082878640882138
# L2 norm :
# 1.0
# time step 288
# differential Entropy :
# 0.0049686370996656366
# approx differential Entropy :
# 3.2063653723767
# L2 norm :
# 1.0
# time step 289
# differential Entropy :
# 0.0049431518600450315
# approx differential Entropy :
# 3.204450240967075
# L2 norm :
# 1.0
# time step 290
# differential Entropy :
# 0.00491787603335122
# approx differential Entropy :
# 3.2025424137284713
# L2 norm :
# 1.0
# time step 291
# differential Entropy :
# 0.00489280721933701
# approx differential Entropy :
# 3.200641835170536
# L2 norm :
# 1.0
# time step 292
# differential Entropy :
# 0.004867943054141928
# approx differential Entropy :
# 3.198748450431676
# L2 norm :
# 1.0
# time step 293
# differential Entropy :
# 0.004843281209510071
# approx differential Entropy :
# 3.196862205271339
# L2 norm :
# 1.0
# time step 294
# differential Entropy :
# 0.004818819392143449
# approx differential Entropy :
# 3.1949830460597033
# L2 norm :
# 1.0
# time step 295
# differential Entropy :
# 0.00479455534305341
# approx differential Entropy :
# 3.193110919769103
# L2 norm :
# 1.0
# time step 296
# differential Entropy :
# 0.0047704868368226355
# approx differential Entropy :
# 3.191245773964691
# L2 norm :
# 1.0
# time step 297
# differential Entropy :
# 0.004746611681085591
# approx differential Entropy :
# 3.1893875567958085
# L2 norm :
# 1.0
# time step 298
# differential Entropy :
# 0.004722927715837576
# approx differential Entropy :
# 3.1875362169871186
# L2 norm :
# 1.0
# time step 299
# differential Entropy :
# 0.004699432812835654
# approx differential Entropy :
# 3.185691703830762
# L2 norm :
# 1.0
# time step 300
# differential Entropy :
# 0.004676124875074721
# approx differential Entropy :
# 3.183853967177053
# L2 norm :
# 1.0
# time step 301
# differential Entropy :
# 0.004653001836055097
# approx differential Entropy :
# 3.1820229574270282
# L2 norm :
# 1.0
# time step 302
# differential Entropy :
# 0.004630061659360065
# approx differential Entropy :
# 3.180198625524142
# L2 norm :
# 1.0
# time step 303
# differential Entropy :
# 0.004607302338120461
# approx differential Entropy :
# 3.1783809229464186
# L2 norm :
# 1.0
# time step 304
# differential Entropy :
# 0.004584721894296496
# approx differential Entropy :
# 3.176569801699041
# L2 norm :
# 1.0
# time step 305
# differential Entropy :
# 0.004562318378318455
# approx differential Entropy :
# 3.174765214305957
# L2 norm :
# 1.0
# time step 306
# differential Entropy :
# 0.0045400898685457785
# approx differential Entropy :
# 3.172967113803276
# L2 norm :
# 1.0
# time step 307
# differential Entropy :
# 0.004518034470670511
# approx differential Entropy :
# 3.171175453731515
# L2 norm :
# 1.0
# time step 308
# differential Entropy :
# 0.004496150317318607
# approx differential Entropy :
# 3.1693901881283124
# L2 norm :
# 1.0
# time step 309
# differential Entropy :
# 0.004474435567513216
# approx differential Entropy :
# 3.167611271521591
# L2 norm :
# 1.0
# time step 310
# differential Entropy :
# 0.004452888406238541
# approx differential Entropy :
# 3.165838658922802
# L2 norm :
# 1.0
# time step 311
# differential Entropy :
# 0.004431507043936433
# approx differential Entropy :
# 3.164072305818971
# L2 norm :
# 1.0
# time step 312
# differential Entropy :
# 0.004410289716105623
# approx differential Entropy :
# 3.1623121681680546
# L2 norm :
# 1.0
# time step 313
# differential Entropy :
# 0.0043892346828222056
# approx differential Entropy :
# 3.1605582023903036
# L2 norm :
# 1.0
# time step 314
# differential Entropy :
# 0.004368340228259134
# approx differential Entropy :
# 3.1588103653628923
# L2 norm :
# 1.0
# time step 315
# differential Entropy :
# 0.004347604660435639
# approx differential Entropy :
# 3.157068614413054
# L2 norm :
# 1.0
# time step 316
# differential Entropy :
# 0.004327026310581362
# approx differential Entropy :
# 3.155332907312849
# L2 norm :
# 1.0
# time step 317
# differential Entropy :
# 0.004306603532899039
# approx differential Entropy :
# 3.153603202271133
# L2 norm :
# 1.0
# time step 318
# differential Entropy :
# 0.004286334704033625
# approx differential Entropy :
# 3.1518794579295526
# L2 norm :
# 1.0
# time step 319
# differential Entropy :
# 0.004266218222841773
# approx differential Entropy :
# 3.1501616333555624
# L2 norm :
# 1.0
# time step 320
# differential Entropy :
# 0.004246252509871489
# approx differential Entropy :
# 3.1484496880365196
# L2 norm :
# 1.0
# time step 321
# differential Entropy :
# 0.004226436007033414
# approx differential Entropy :
# 3.14674358187404
# L2 norm :
# 1.0
# time step 322
# differential Entropy :
# 0.004206767177291991
# approx differential Entropy :
# 3.145043275178937
# L2 norm :
# 1.0
# time step 323
# differential Entropy :
# 0.004187244504218496
# approx differential Entropy :
# 3.1433487286651345
# L2 norm :
# 1.0
# time step 324
# differential Entropy :
# 0.0041678664916597235
# approx differential Entropy :
# 3.1416599034440784
# L2 norm :
# 1.0
# time step 325
# differential Entropy :
# 0.004148631663505526
# approx differential Entropy :
# 3.1399767610200513
# L2 norm :
# 1.0
# time step 326
# differential Entropy :
# 0.0041295385631930775
# approx differential Entropy :
# 3.138299263284262
# L2 norm :
# 1.0
# time step 327
# differential Entropy :
# 0.004110585753457924
# approx differential Entropy :
# 3.136627372509889
# L2 norm :
# 1.0
# time step 328
# differential Entropy :
# 0.004091771816065872
# approx differential Entropy :
# 3.1349610513474544
# L2 norm :
# 1.0
# time step 329
# differential Entropy :
# 0.004073095351371339
# approx differential Entropy :
# 3.1333002628184805
# L2 norm :
# 1.0
# time step 330
# differential Entropy :
# 0.00405455497810275
# approx differential Entropy :
# 3.1316449703125713
# L2 norm :
# 1.0
# time step 331
# differential Entropy :
# 0.004036149333022974
# approx differential Entropy :
# 3.129995137580683
# L2 norm :
# 1.0
# time step 332
# differential Entropy :
# 0.004017877070699142
# approx differential Entropy :
# 3.128350728731663
# L2 norm :
# 1.0
# time step 333
# differential Entropy :
# 0.003999736863063923
# approx differential Entropy :
# 3.126711708226623
# L2 norm :
# 1.0
# time step 334
# differential Entropy :
# 0.003981727399242873
# approx differential Entropy :
# 3.1250780408750014
# L2 norm :
# 1.0
# time step 335
# differential Entropy :
# 0.003963847385359768
# approx differential Entropy :
# 3.123449691830049
# L2 norm :
# 1.0
#   0%|          | 0/10 [00:14<?, ?it/s]
# time step 336
# differential Entropy :
# 0.003946095544004415
# approx differential Entropy :
# 3.121826626583798
# L2 norm :
# 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 25
#      17 nHess_0 = np.array([
#      18     [ 0.58396333, -0.36175317,  0.08181892, -0.01999662],
#      19     [-0.36175317,  0.47667193,  0.02797142, -0.05730899],
#      20     [ 0.08181892,  0.02797142,  0.2620719 ,  0.03275013],
#      21     [-0.01999662, -0.05730899,  0.03275013,  0.27729285]
#      22     ]) # Eigvals : 0.9, 0.3, 0.3, 0.1
#      23 iterations = 10
# ---> 25 Run_Synthetic(model_name, dim, alpha, true_theta, num_t, MAP_0, nHess_0, iterations)
#      26 #'''
#      28 ''' Realworld Case Experiments '''
#
# Cell In[71], line 228, in Run_Synthetic(model_name, dim, alpha, true_theta, num_t, MAP_0, nHess_0, iterations)
#     226 exp = Experiment_Synthetic(Algo, dim, f, true_theta, num_t, MAP_0, nHess_0)
#     227 for iter in tqdm(range(iterations)) :
# --> 228     data = exp.iter_t()
#     229     Data.append(data)
#     230     print(iter)
#
# Cell In[71], line 211, in Experiment_Synthetic.iter_t(self)
#     209 # Belief by Bayesian update
#     210 y = 1 if self.answers[self.Belief.t] < true_f else 0
# --> 211 self.Belief.bayesian_update(x, y)
#     213 end_time = time.time()
#     214 self.Belief.Record.data['time'].append(end_time-start_time)
#
# Cell In[71], line 125, in Belief.bayesian_update(self, x, y)
#     120     hessian = lambda theta : self.nHess_0 + sum([( (1 - self.y_t[idx]) * self.f(theta,self.x_t[idx]) / (1-self.f(theta,self.x_t[idx])) + self.y_t[idx]) * np.diag(sigmoid(self.x_t[idx] + theta).reshape(-1) * (1 - sigmoid(self.x_t[idx] + theta).reshape(-1)))
#     121                                                  + (1 - self.y_t[idx]) * (1 - sigmoid(self.x_t[idx] + theta)).T @ (1 - sigmoid(self.x_t[idx] + theta)) * self.f(theta,self.x_t[idx]) / ((1-self.f(theta,self.x_t[idx]))**2)
#     122                                                  for idx in range(len(self.x_t))])
#     124 # Laplace Approximation
# --> 125 opt_response = minimize(func, self.MAP, jac=gradient, hess=hessian, method='trust-ncg')
#     126 self.MAP = opt_response.x
#     127 self.nHess = hessian(self.MAP)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minimize.py:732, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     729     res = _minimize_dogleg(fun, x0, args, jac, hess,
#     730                            callback=callback, **options)
#     731 elif meth == 'trust-ncg':
# --> 732     res = _minimize_trust_ncg(fun, x0, args, jac, hess, hessp,
#     733                               callback=callback, **options)
#     734 elif meth == 'trust-krylov':
#     735     res = _minimize_trust_krylov(fun, x0, args, jac, hess, hessp,
#     736                                  callback=callback, **options)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_trustregion_ncg.py:37, in _minimize_trust_ncg(fun, x0, args, jac, hess, hessp, **trust_region_options)
#      34 if hess is None and hessp is None:
#      35     raise ValueError('Either the Hessian or the Hessian-vector product '
#      36                      'is required for Newton-CG trust-region minimization')
# ---> 37 return _minimize_trust_region(fun, x0, args=args, jac=jac, hess=hess,
#      38                               hessp=hessp, subproblem=CGSteihaugSubproblem,
#      39                               **trust_region_options)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_trustregion.py:238, in _minimize_trust_region(fun, x0, args, jac, hess, hessp, subproblem, initial_trust_radius, max_trust_radius, eta, gtol, maxiter, disp, return_all, callback, inexact, **unknown_options)
#     235 m_proposed = subproblem(x_proposed, fun, jac, hess, hessp)
#     237 # evaluate the ratio defined in equation (4.4)
# --> 238 actual_reduction = m.fun - m_proposed.fun
#     239 predicted_reduction = m.fun - predicted_value
#     240 if predicted_reduction <= 0:
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_trustregion.py:60, in BaseQuadraticSubproblem.fun(self)
#      58 """Value of objective function at current iteration."""
#      59 if self._f is None:
# ---> 60     self._f = self._fun(self._x)
#      61 return self._f
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_differentiable_functions.py:278, in ScalarFunction.fun(self, x)
#     276 if not np.array_equal(x, self.x):
#     277     self._update_x_impl(x)
# --> 278 self._update_fun()
#     279 return self.f
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_differentiable_functions.py:262, in ScalarFunction._update_fun(self)
#     260 def _update_fun(self):
#     261     if not self.f_updated:
# --> 262         self._update_fun_impl()
#     263         self.f_updated = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_differentiable_functions.py:163, in ScalarFunction.__init__.<locals>.update_fun()
#     162 def update_fun():
# --> 163     self.f = fun_wrapped(self.x)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# Cell In[71], line 106, in Belief.bayesian_update.<locals>.<lambda>(theta)
#     103 self.x_t.append(x)
#     104 self.y_t.append(y)
# --> 106 NLPosterior = lambda theta : -sum([self.LL_t[L_idx](theta) for L_idx in range(len(self.LL_t))])
#     107 func = NLPosterior
#     109 # Analytic gradient and hessian of each models
#
# Cell In[71], line 106, in <listcomp>(.0)
#     103 self.x_t.append(x)
#     104 self.y_t.append(y)
# --> 106 NLPosterior = lambda theta : -sum([self.LL_t[L_idx](theta) for L_idx in range(len(self.LL_t))])
#     107 func = NLPosterior
#     109 # Analytic gradient and hessian of each models
#
# Cell In[71], line 101, in Belief.bayesian_update.<locals>.<lambda>(theta)
#     100 def bayesian_update(self, x, y):
# --> 101     LL = lambda theta : np.log( self.f(theta, x).reshape(-1) if y==1 else 1-self.f(theta, x).reshape(-1) ) # Log Likelihood
#     102     self.LL_t.append(LL)
#     103     self.x_t.append(x)
#
# KeyboardInterrupt:
